# %% [markdown]
# # Importing Libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from pathlib import Path

# %% [markdown]
# # Data Preprocessing

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=128,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=True,

)
# Out:
# Found 70295 files belonging to 38 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,

)
# Out:
# Found 17572 files belonging to 38 classes.

# %%
training_set
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 38), dtype=tf.float32, name=None))>

# %% [markdown]
# # Building Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ## MobileNet Model

# %%
import h5py
print(h5py.__version__)
# Out:
# 3.9.0

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
base_model = InceptionV3(input_shape = (128, 128, 3), include_top = False, weights = 'imagenet')

# %% [markdown]
# ### Fine-Tuning

# %%
# Add custom classification layers on top of the pre-trained model
x = Flatten()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.25)(x)  # Add dropout to reduce overfitting
x = Dense(38, activation='softmax')(x)  # Adjust the output size based on your task

# %%
base_model.trainable = True

set_trainable = False

for layer in base_model.layers:
    if layer.name == 'block_14_expand':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
base_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 63, 63, 32)   864         ['input_5[0][0]']
#
#  batch_normalization_376 (Batch  (None, 63, 63, 32)  96          ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_376 (Activation)    (None, 63, 63, 32)   0           ['batch_normalization_376[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 61, 61, 32)   9216        ['activation_376[0][0]']
#
#  batch_normalization_377 (Batch  (None, 61, 61, 32)  96          ['conv2d_377[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 61, 61, 32)   0           ['batch_normalization_377[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 61, 61, 64)   18432       ['activation_377[0][0]']
#
#  batch_normalization_378 (Batch  (None, 61, 61, 64)  192         ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 61, 61, 64)   0           ['batch_normalization_378[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 30, 30, 64)  0           ['activation_378[0][0]']
#  )
#
#  conv2d_379 (Conv2D)            (None, 30, 30, 80)   5120        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_379 (Batch  (None, 30, 30, 80)  240         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 30, 30, 80)   0           ['batch_normalization_379[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 28, 28, 192)  138240      ['activation_379[0][0]']
#
#  batch_normalization_380 (Batch  (None, 28, 28, 192)  576        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 28, 28, 192)  0           ['batch_normalization_380[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 13, 13, 192)  0          ['activation_380[0][0]']
#  )
#
#  conv2d_384 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_384 (Batch  (None, 13, 13, 64)  192         ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_384[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 13, 13, 48)   9216        ['max_pooling2d_17[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_384[0][0]']
#
#  batch_normalization_382 (Batch  (None, 13, 13, 48)  144         ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 13, 13, 96)  288         ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_382[0][0]']
#
#  activation_385 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_385[0][0]']
#
#  average_pooling2d_36 (AverageP  (None, 13, 13, 192)  0          ['max_pooling2d_17[0][0]']
#  ooling2D)
#
#  conv2d_381 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 13, 13, 32)   6144        ['average_pooling2d_36[0][0]']
#
#  batch_normalization_381 (Batch  (None, 13, 13, 64)  192         ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_383 (Batch  (None, 13, 13, 64)  192         ['conv2d_383[0][0]']
#  Normalization)
#
#  batch_normalization_386 (Batch  (None, 13, 13, 96)  288         ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 13, 13, 32)  96          ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_381[0][0]']
#
#  activation_383 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_383[0][0]']
#
#  activation_386 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_386[0][0]']
#
#  activation_387 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_387[0][0]']
#
#  mixed0 (Concatenate)           (None, 13, 13, 256)  0           ['activation_381[0][0]',
#                                                                   'activation_383[0][0]',
#                                                                   'activation_386[0][0]',
#                                                                   'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_391 (Batch  (None, 13, 13, 64)  192         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_391[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 13, 13, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_391[0][0]']
#
#  batch_normalization_389 (Batch  (None, 13, 13, 48)  144         ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_392 (Batch  (None, 13, 13, 96)  288         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_389[0][0]']
#
#  activation_392 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_392[0][0]']
#
#  average_pooling2d_37 (AverageP  (None, 13, 13, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_388 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 13, 13, 64)   16384       ['average_pooling2d_37[0][0]']
#
#  batch_normalization_388 (Batch  (None, 13, 13, 64)  192         ['conv2d_388[0][0]']
#  Normalization)
#
#  batch_normalization_390 (Batch  (None, 13, 13, 64)  192         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 13, 13, 96)  288         ['conv2d_393[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 13, 13, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_388 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_388[0][0]']
#
#  activation_390 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_393[0][0]']
#
#  activation_394 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_394[0][0]']
#
#  mixed1 (Concatenate)           (None, 13, 13, 288)  0           ['activation_388[0][0]',
#                                                                   'activation_390[0][0]',
#                                                                   'activation_393[0][0]',
#                                                                   'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_398 (Batch  (None, 13, 13, 64)  192         ['conv2d_398[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_398[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 13, 13, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_398[0][0]']
#
#  batch_normalization_396 (Batch  (None, 13, 13, 48)  144         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_399 (Batch  (None, 13, 13, 96)  288         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_396[0][0]']
#
#  activation_399 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_399[0][0]']
#
#  average_pooling2d_38 (AverageP  (None, 13, 13, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_395 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 13, 13, 64)   18432       ['average_pooling2d_38[0][0]']
#
#  batch_normalization_395 (Batch  (None, 13, 13, 64)  192         ['conv2d_395[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 13, 13, 64)  192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_400 (Batch  (None, 13, 13, 96)  288         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 13, 13, 64)  192         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_395[0][0]']
#
#  activation_397 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_397[0][0]']
#
#  activation_400 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_400[0][0]']
#
#  activation_401 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_401[0][0]']
#
#  mixed2 (Concatenate)           (None, 13, 13, 288)  0           ['activation_395[0][0]',
#                                                                   'activation_397[0][0]',
#                                                                   'activation_400[0][0]',
#                                                                   'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_403 (Batch  (None, 13, 13, 64)  192         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 13, 13, 96)  288         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 6, 6, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 6, 6, 96)     82944       ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 6, 6, 384)   1152        ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 6, 6, 96)    288         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 6, 6, 96)     0           ['batch_normalization_405[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 6, 6, 288)   0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 6, 6, 768)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]',
#                                                                   'max_pooling2d_18[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_410 (Batch  (None, 6, 6, 128)   384         ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_410[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_410[0][0]']
#
#  batch_normalization_411 (Batch  (None, 6, 6, 128)   384         ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_411[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_411[0][0]']
#
#  batch_normalization_407 (Batch  (None, 6, 6, 128)   384         ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_412 (Batch  (None, 6, 6, 128)   384         ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_407[0][0]']
#
#  activation_412 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_412[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_412[0][0]']
#
#  batch_normalization_408 (Batch  (None, 6, 6, 128)   384         ['conv2d_408[0][0]']
#  Normalization)
#
#  batch_normalization_413 (Batch  (None, 6, 6, 128)   384         ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_408[0][0]']
#
#  activation_413 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_413[0][0]']
#
#  average_pooling2d_39 (AverageP  (None, 6, 6, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_406 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_39[0][0]']
#
#  batch_normalization_406 (Batch  (None, 6, 6, 192)   576         ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_409 (Batch  (None, 6, 6, 192)   576         ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_414 (Batch  (None, 6, 6, 192)   576         ['conv2d_414[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 6, 6, 192)   576         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_406[0][0]']
#
#  activation_409 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_409[0][0]']
#
#  activation_414 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_414[0][0]']
#
#  activation_415 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_415[0][0]']
#
#  mixed4 (Concatenate)           (None, 6, 6, 768)    0           ['activation_406[0][0]',
#                                                                   'activation_409[0][0]',
#                                                                   'activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_420 (Batch  (None, 6, 6, 160)   480         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_420[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_420[0][0]']
#
#  batch_normalization_421 (Batch  (None, 6, 6, 160)   480         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_421[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_421[0][0]']
#
#  batch_normalization_417 (Batch  (None, 6, 6, 160)   480         ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 6, 6, 160)   480         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_417 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_417[0][0]']
#
#  activation_422 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_422[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_422[0][0]']
#
#  batch_normalization_418 (Batch  (None, 6, 6, 160)   480         ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 6, 6, 160)   480         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_418[0][0]']
#
#  activation_423 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_423[0][0]']
#
#  average_pooling2d_40 (AverageP  (None, 6, 6, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_416 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_40[0][0]']
#
#  batch_normalization_416 (Batch  (None, 6, 6, 192)   576         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_419 (Batch  (None, 6, 6, 192)   576         ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 6, 6, 192)   576         ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 6, 6, 192)   576         ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_416[0][0]']
#
#  activation_419 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_419[0][0]']
#
#  activation_424 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_424[0][0]']
#
#  activation_425 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_425[0][0]']
#
#  mixed5 (Concatenate)           (None, 6, 6, 768)    0           ['activation_416[0][0]',
#                                                                   'activation_419[0][0]',
#                                                                   'activation_424[0][0]',
#                                                                   'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_430 (Batch  (None, 6, 6, 160)   480         ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_430[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_430[0][0]']
#
#  batch_normalization_431 (Batch  (None, 6, 6, 160)   480         ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_431[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_431[0][0]']
#
#  batch_normalization_427 (Batch  (None, 6, 6, 160)   480         ['conv2d_427[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 6, 6, 160)   480         ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_427[0][0]']
#
#  activation_432 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_432[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_427[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_432[0][0]']
#
#  batch_normalization_428 (Batch  (None, 6, 6, 160)   480         ['conv2d_428[0][0]']
#  Normalization)
#
#  batch_normalization_433 (Batch  (None, 6, 6, 160)   480         ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_428[0][0]']
#
#  activation_433 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_433[0][0]']
#
#  average_pooling2d_41 (AverageP  (None, 6, 6, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_426 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_428[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_433[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_41[0][0]']
#
#  batch_normalization_426 (Batch  (None, 6, 6, 192)   576         ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 6, 6, 192)   576         ['conv2d_429[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 6, 6, 192)   576         ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 6, 6, 192)   576         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_426[0][0]']
#
#  activation_429 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_429[0][0]']
#
#  activation_434 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_434[0][0]']
#
#  activation_435 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_435[0][0]']
#
#  mixed6 (Concatenate)           (None, 6, 6, 768)    0           ['activation_426[0][0]',
#                                                                   'activation_429[0][0]',
# ...
#  mixed8 (Concatenate)           (None, 2, 2, 1280)   0           ['activation_447[0][0]',
#                                                                   'activation_451[0][0]',
#                                                                   'max_pooling2d_19[0][0]']
#
#  conv2d_456 (Conv2D)            (None, 2, 2, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_456 (Batch  (None, 2, 2, 448)   1344        ['conv2d_456[0][0]']
#  Normalization)
#
#  activation_456 (Activation)    (None, 2, 2, 448)    0           ['batch_normalization_456[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 2, 2, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 2, 2, 384)    1548288     ['activation_456[0][0]']
#
#  batch_normalization_453 (Batch  (None, 2, 2, 384)   1152        ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_457 (Batch  (None, 2, 2, 384)   1152        ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_453 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_453[0][0]']
#
#  activation_457 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_457[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_457[0][0]']
#
#  average_pooling2d_43 (AverageP  (None, 2, 2, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_452 (Conv2D)            (None, 2, 2, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_454 (Batch  (None, 2, 2, 384)   1152        ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_455 (Batch  (None, 2, 2, 384)   1152        ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 2, 2, 384)   1152        ['conv2d_458[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 2, 2, 384)   1152        ['conv2d_459[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 2, 2, 192)    245760      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_452 (Batch  (None, 2, 2, 320)   960         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_454[0][0]']
#
#  activation_455 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_455[0][0]']
#
#  activation_458 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_458[0][0]']
#
#  activation_459 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_459[0][0]']
#
#  batch_normalization_460 (Batch  (None, 2, 2, 192)   576         ['conv2d_460[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 2, 2, 320)    0           ['batch_normalization_452[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 2, 2, 768)    0           ['activation_454[0][0]',
#                                                                   'activation_455[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 768)    0           ['activation_458[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_460[0][0]']
#
#  mixed9 (Concatenate)           (None, 2, 2, 2048)   0           ['activation_452[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 2, 2, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_465 (Batch  (None, 2, 2, 448)   1344        ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_465 (Activation)    (None, 2, 2, 448)    0           ['batch_normalization_465[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 2, 2, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 2, 2, 384)    1548288     ['activation_465[0][0]']
#
#  batch_normalization_462 (Batch  (None, 2, 2, 384)   1152        ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_466 (Batch  (None, 2, 2, 384)   1152        ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_462 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_462[0][0]']
#
#  activation_466 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_466[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_466[0][0]']
#
#  average_pooling2d_44 (AverageP  (None, 2, 2, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_461 (Conv2D)            (None, 2, 2, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_463 (Batch  (None, 2, 2, 384)   1152        ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_464 (Batch  (None, 2, 2, 384)   1152        ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_467 (Batch  (None, 2, 2, 384)   1152        ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_468 (Batch  (None, 2, 2, 384)   1152        ['conv2d_468[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 2, 2, 192)    393216      ['average_pooling2d_44[0][0]']
#
#  batch_normalization_461 (Batch  (None, 2, 2, 320)   960         ['conv2d_461[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_463[0][0]']
#
#  activation_464 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_464[0][0]']
#
#  activation_467 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_467[0][0]']
#
#  activation_468 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_468[0][0]']
#
#  batch_normalization_469 (Batch  (None, 2, 2, 192)   576         ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_461 (Activation)    (None, 2, 2, 320)    0           ['batch_normalization_461[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 2, 2, 768)    0           ['activation_463[0][0]',
#                                                                   'activation_464[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 2, 2, 768)    0           ['activation_467[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_469[0][0]']
#
#  mixed10 (Concatenate)          (None, 2, 2, 2048)   0           ['activation_461[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'activation_469[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %% [markdown]
# ### Add custom classifcation layer

# %%
# # Normalize
# def process(image,label):
#     image = tf.cast(image/255. ,tf.float32)
#     return image,label

# train_ds = training_set.map(process)
# validation_ds = validation_set.map(process)

# %%
# Create the fine-tuned model
InceptModel = Model(inputs=base_model.input, outputs=x)
optimizer_SGD = SGD(learning_rate=1e-4, momentum=0.9)

# Compile the model
InceptModel.compile(
    
    optimizer=optimizer_SGD,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
InceptModel.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 63, 63, 32)   864         ['input_5[0][0]']
#
#  batch_normalization_376 (Batch  (None, 63, 63, 32)  96          ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_376 (Activation)    (None, 63, 63, 32)   0           ['batch_normalization_376[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 61, 61, 32)   9216        ['activation_376[0][0]']
#
#  batch_normalization_377 (Batch  (None, 61, 61, 32)  96          ['conv2d_377[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 61, 61, 32)   0           ['batch_normalization_377[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 61, 61, 64)   18432       ['activation_377[0][0]']
#
#  batch_normalization_378 (Batch  (None, 61, 61, 64)  192         ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 61, 61, 64)   0           ['batch_normalization_378[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 30, 30, 64)  0           ['activation_378[0][0]']
#  )
#
#  conv2d_379 (Conv2D)            (None, 30, 30, 80)   5120        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_379 (Batch  (None, 30, 30, 80)  240         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 30, 30, 80)   0           ['batch_normalization_379[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 28, 28, 192)  138240      ['activation_379[0][0]']
#
#  batch_normalization_380 (Batch  (None, 28, 28, 192)  576        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 28, 28, 192)  0           ['batch_normalization_380[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 13, 13, 192)  0          ['activation_380[0][0]']
#  )
#
#  conv2d_384 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_384 (Batch  (None, 13, 13, 64)  192         ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_384[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 13, 13, 48)   9216        ['max_pooling2d_17[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_384[0][0]']
#
#  batch_normalization_382 (Batch  (None, 13, 13, 48)  144         ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 13, 13, 96)  288         ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_382[0][0]']
#
#  activation_385 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_385[0][0]']
#
#  average_pooling2d_36 (AverageP  (None, 13, 13, 192)  0          ['max_pooling2d_17[0][0]']
#  ooling2D)
#
#  conv2d_381 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 13, 13, 32)   6144        ['average_pooling2d_36[0][0]']
#
#  batch_normalization_381 (Batch  (None, 13, 13, 64)  192         ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_383 (Batch  (None, 13, 13, 64)  192         ['conv2d_383[0][0]']
#  Normalization)
#
#  batch_normalization_386 (Batch  (None, 13, 13, 96)  288         ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 13, 13, 32)  96          ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_381[0][0]']
#
#  activation_383 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_383[0][0]']
#
#  activation_386 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_386[0][0]']
#
#  activation_387 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_387[0][0]']
#
#  mixed0 (Concatenate)           (None, 13, 13, 256)  0           ['activation_381[0][0]',
#                                                                   'activation_383[0][0]',
#                                                                   'activation_386[0][0]',
#                                                                   'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_391 (Batch  (None, 13, 13, 64)  192         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_391[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 13, 13, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_391[0][0]']
#
#  batch_normalization_389 (Batch  (None, 13, 13, 48)  144         ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_392 (Batch  (None, 13, 13, 96)  288         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_389[0][0]']
#
#  activation_392 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_392[0][0]']
#
#  average_pooling2d_37 (AverageP  (None, 13, 13, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_388 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 13, 13, 64)   16384       ['average_pooling2d_37[0][0]']
#
#  batch_normalization_388 (Batch  (None, 13, 13, 64)  192         ['conv2d_388[0][0]']
#  Normalization)
#
#  batch_normalization_390 (Batch  (None, 13, 13, 64)  192         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 13, 13, 96)  288         ['conv2d_393[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 13, 13, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_388 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_388[0][0]']
#
#  activation_390 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_393[0][0]']
#
#  activation_394 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_394[0][0]']
#
#  mixed1 (Concatenate)           (None, 13, 13, 288)  0           ['activation_388[0][0]',
#                                                                   'activation_390[0][0]',
#                                                                   'activation_393[0][0]',
#                                                                   'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_398 (Batch  (None, 13, 13, 64)  192         ['conv2d_398[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_398[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 13, 13, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_398[0][0]']
#
#  batch_normalization_396 (Batch  (None, 13, 13, 48)  144         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_399 (Batch  (None, 13, 13, 96)  288         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_396[0][0]']
#
#  activation_399 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_399[0][0]']
#
#  average_pooling2d_38 (AverageP  (None, 13, 13, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_395 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 13, 13, 64)   18432       ['average_pooling2d_38[0][0]']
#
#  batch_normalization_395 (Batch  (None, 13, 13, 64)  192         ['conv2d_395[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 13, 13, 64)  192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_400 (Batch  (None, 13, 13, 96)  288         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 13, 13, 64)  192         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_395[0][0]']
#
#  activation_397 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_397[0][0]']
#
#  activation_400 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_400[0][0]']
#
#  activation_401 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_401[0][0]']
#
#  mixed2 (Concatenate)           (None, 13, 13, 288)  0           ['activation_395[0][0]',
#                                                                   'activation_397[0][0]',
#                                                                   'activation_400[0][0]',
#                                                                   'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_403 (Batch  (None, 13, 13, 64)  192         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 13, 13, 96)  288         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 6, 6, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 6, 6, 96)     82944       ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 6, 6, 384)   1152        ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 6, 6, 96)    288         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 6, 6, 96)     0           ['batch_normalization_405[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 6, 6, 288)   0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 6, 6, 768)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]',
#                                                                   'max_pooling2d_18[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_410 (Batch  (None, 6, 6, 128)   384         ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_410[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_410[0][0]']
#
#  batch_normalization_411 (Batch  (None, 6, 6, 128)   384         ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_411[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_411[0][0]']
#
#  batch_normalization_407 (Batch  (None, 6, 6, 128)   384         ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_412 (Batch  (None, 6, 6, 128)   384         ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_407[0][0]']
#
#  activation_412 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_412[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_412[0][0]']
#
#  batch_normalization_408 (Batch  (None, 6, 6, 128)   384         ['conv2d_408[0][0]']
#  Normalization)
#
#  batch_normalization_413 (Batch  (None, 6, 6, 128)   384         ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_408[0][0]']
#
#  activation_413 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_413[0][0]']
#
#  average_pooling2d_39 (AverageP  (None, 6, 6, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_406 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_39[0][0]']
#
#  batch_normalization_406 (Batch  (None, 6, 6, 192)   576         ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_409 (Batch  (None, 6, 6, 192)   576         ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_414 (Batch  (None, 6, 6, 192)   576         ['conv2d_414[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 6, 6, 192)   576         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_406[0][0]']
#
#  activation_409 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_409[0][0]']
#
#  activation_414 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_414[0][0]']
#
#  activation_415 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_415[0][0]']
#
#  mixed4 (Concatenate)           (None, 6, 6, 768)    0           ['activation_406[0][0]',
#                                                                   'activation_409[0][0]',
#                                                                   'activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_420 (Batch  (None, 6, 6, 160)   480         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_420[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_420[0][0]']
#
#  batch_normalization_421 (Batch  (None, 6, 6, 160)   480         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_421[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_421[0][0]']
#
#  batch_normalization_417 (Batch  (None, 6, 6, 160)   480         ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 6, 6, 160)   480         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_417 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_417[0][0]']
#
#  activation_422 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_422[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_422[0][0]']
#
#  batch_normalization_418 (Batch  (None, 6, 6, 160)   480         ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 6, 6, 160)   480         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_418[0][0]']
#
#  activation_423 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_423[0][0]']
#
#  average_pooling2d_40 (AverageP  (None, 6, 6, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_416 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_40[0][0]']
#
#  batch_normalization_416 (Batch  (None, 6, 6, 192)   576         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_419 (Batch  (None, 6, 6, 192)   576         ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 6, 6, 192)   576         ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 6, 6, 192)   576         ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_416[0][0]']
#
#  activation_419 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_419[0][0]']
#
#  activation_424 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_424[0][0]']
#
#  activation_425 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_425[0][0]']
#
#  mixed5 (Concatenate)           (None, 6, 6, 768)    0           ['activation_416[0][0]',
#                                                                   'activation_419[0][0]',
#                                                                   'activation_424[0][0]',
#                                                                   'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_430 (Batch  (None, 6, 6, 160)   480         ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_430[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_430[0][0]']
#
#  batch_normalization_431 (Batch  (None, 6, 6, 160)   480         ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_431[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_431[0][0]']
#
#  batch_normalization_427 (Batch  (None, 6, 6, 160)   480         ['conv2d_427[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 6, 6, 160)   480         ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_427[0][0]']
#
#  activation_432 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_432[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_427[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_432[0][0]']
#
#  batch_normalization_428 (Batch  (None, 6, 6, 160)   480         ['conv2d_428[0][0]']
#  Normalization)
#
#  batch_normalization_433 (Batch  (None, 6, 6, 160)   480         ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_428[0][0]']
#
#  activation_433 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_433[0][0]']
#
#  average_pooling2d_41 (AverageP  (None, 6, 6, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_426 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_428[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_433[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_41[0][0]']
#
#  batch_normalization_426 (Batch  (None, 6, 6, 192)   576         ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 6, 6, 192)   576         ['conv2d_429[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 6, 6, 192)   576         ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 6, 6, 192)   576         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_426[0][0]']
#
#  activation_429 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_429[0][0]']
#
#  activation_434 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_434[0][0]']
#
#  activation_435 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_435[0][0]']
#
#  mixed6 (Concatenate)           (None, 6, 6, 768)    0           ['activation_426[0][0]',
#                                                                   'activation_429[0][0]',
# ...
#
#  activation_456 (Activation)    (None, 2, 2, 448)    0           ['batch_normalization_456[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 2, 2, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 2, 2, 384)    1548288     ['activation_456[0][0]']
#
#  batch_normalization_453 (Batch  (None, 2, 2, 384)   1152        ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_457 (Batch  (None, 2, 2, 384)   1152        ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_453 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_453[0][0]']
#
#  activation_457 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_457[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_457[0][0]']
#
#  average_pooling2d_43 (AverageP  (None, 2, 2, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_452 (Conv2D)            (None, 2, 2, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_454 (Batch  (None, 2, 2, 384)   1152        ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_455 (Batch  (None, 2, 2, 384)   1152        ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 2, 2, 384)   1152        ['conv2d_458[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 2, 2, 384)   1152        ['conv2d_459[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 2, 2, 192)    245760      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_452 (Batch  (None, 2, 2, 320)   960         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_454[0][0]']
#
#  activation_455 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_455[0][0]']
#
#  activation_458 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_458[0][0]']
#
#  activation_459 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_459[0][0]']
#
#  batch_normalization_460 (Batch  (None, 2, 2, 192)   576         ['conv2d_460[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 2, 2, 320)    0           ['batch_normalization_452[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 2, 2, 768)    0           ['activation_454[0][0]',
#                                                                   'activation_455[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 768)    0           ['activation_458[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_460[0][0]']
#
#  mixed9 (Concatenate)           (None, 2, 2, 2048)   0           ['activation_452[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 2, 2, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_465 (Batch  (None, 2, 2, 448)   1344        ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_465 (Activation)    (None, 2, 2, 448)    0           ['batch_normalization_465[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 2, 2, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 2, 2, 384)    1548288     ['activation_465[0][0]']
#
#  batch_normalization_462 (Batch  (None, 2, 2, 384)   1152        ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_466 (Batch  (None, 2, 2, 384)   1152        ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_462 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_462[0][0]']
#
#  activation_466 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_466[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_466[0][0]']
#
#  average_pooling2d_44 (AverageP  (None, 2, 2, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_461 (Conv2D)            (None, 2, 2, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_463 (Batch  (None, 2, 2, 384)   1152        ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_464 (Batch  (None, 2, 2, 384)   1152        ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_467 (Batch  (None, 2, 2, 384)   1152        ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_468 (Batch  (None, 2, 2, 384)   1152        ['conv2d_468[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 2, 2, 192)    393216      ['average_pooling2d_44[0][0]']
#
#  batch_normalization_461 (Batch  (None, 2, 2, 320)   960         ['conv2d_461[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_463[0][0]']
#
#  activation_464 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_464[0][0]']
#
#  activation_467 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_467[0][0]']
#
#  activation_468 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_468[0][0]']
#
#  batch_normalization_469 (Batch  (None, 2, 2, 192)   576         ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_461 (Activation)    (None, 2, 2, 320)    0           ['batch_normalization_461[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 2, 2, 768)    0           ['activation_463[0][0]',
#                                                                   'activation_464[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 2, 2, 768)    0           ['activation_467[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_469[0][0]']
#
#  mixed10 (Concatenate)          (None, 2, 2, 2048)   0           ['activation_461[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'activation_469[0][0]']
#
#  flatten_1 (Flatten)            (None, 8192)         0           ['mixed10[0][0]']
#
#  dense_2 (Dense)                (None, 256)          2097408     ['flatten_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 38)           9766        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23,909,958
# Trainable params: 2,107,174
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
history_Incept = InceptModel.fit(training_set,epochs=10,validation_data=validation_set)
# Out:
# Epoch 1/10
# 550/550 [==============================] - 844s 2s/step - loss: 4.8226 - accuracy: 0.0373 - val_loss: 3.5823 - val_accuracy: 0.0525
# Epoch 2/10
# 550/550 [==============================] - 671s 1s/step - loss: 3.6132 - accuracy: 0.0398 - val_loss: 3.5492 - val_accuracy: 0.0625
# Epoch 3/10
# 550/550 [==============================] - 677s 1s/step - loss: 3.5793 - accuracy: 0.0515 - val_loss: 3.5412 - val_accuracy: 0.0657
# Epoch 4/10
# 550/550 [==============================] - 674s 1s/step - loss: 3.5696 - accuracy: 0.0548 - val_loss: 3.5258 - val_accuracy: 0.0734
# Epoch 5/10
# 550/550 [==============================] - 667s 1s/step - loss: 3.5603 - accuracy: 0.0556 - val_loss: 3.5146 - val_accuracy: 0.0697
# Epoch 6/10
# 550/550 [==============================] - 666s 1s/step - loss: 3.5523 - accuracy: 0.0577 - val_loss: 3.5165 - val_accuracy: 0.0763
# Epoch 7/10
# 550/550 [==============================] - 669s 1s/step - loss: 3.5445 - accuracy: 0.0602 - val_loss: 3.4925 - val_accuracy: 0.0754
# Epoch 8/10
# 550/550 [==============================] - 670s 1s/step - loss: 3.5311 - accuracy: 0.0627 - val_loss: 3.5073 - val_accuracy: 0.0702
# Epoch 9/10
# 550/550 [==============================] - 666s 1s/step - loss: 3.5208 - accuracy: 0.0640 - val_loss: 3.4834 - val_accuracy: 0.0769
# Epoch 10/10
# 550/550 [==============================] - 667s 1s/step - loss: 3.5070 - accuracy: 0.0657 - val_loss: 3.5100 - val_accuracy: 0.0730

# %%
#Training set Accuracy
train_loss, train_acc = InceptModel.evaluate(training_set)
print('Training accuracy:', train_acc)
# Out:
# 550/550 [==============================] - 520s 945ms/step - loss: 3.5028 - accuracy: 0.0742
# Training accuracy: 0.07421580702066422

# %%
#Validation set Accuracy
val_loss, val_acc = InceptModel.evaluate(validation_set)
print('Validation accuracy:', val_acc)
# Out:
# 550/550 [==============================] - 152s 277ms/step - loss: 3.5100 - accuracy: 0.0730
# Validation accuracy: 0.07301388680934906

# %%
InceptModel.save('InceptModel.keras')

# %%
history_Incept.history #Return Dictionary of history
# Out:
# {'loss': [4.822634220123291,
#   3.61321759223938,
#   3.5793099403381348,
#   3.5696442127227783,
#   3.5602669715881348,
#   3.5522823333740234,
#   3.5444819927215576,
#   3.5311243534088135,
#   3.52079439163208,
#   3.506989002227783],
#  'accuracy': [0.037342626601457596,
#   0.039789456874132156,
#   0.05152571201324463,
#   0.05476918816566467,
#   0.055622734129428864,
#   0.05767124146223068,
#   0.0602034293115139,
#   0.06273561716079712,
#   0.06398747861385345,
#   0.06573724746704102],
#  'val_loss': [3.5822787284851074,
#   3.5491538047790527,
#   3.541217803955078,
#   3.5258047580718994,
#   3.514646530151367,
#   3.5165340900421143,
#   3.492487668991089,
#   3.507291316986084,
#   3.483358144760132,
#   3.5100181102752686],
#  'val_accuracy': [0.05246983841061592,
#   0.06254268437623978,
#   0.06572957336902618,
#   0.07341224700212479,
#   0.06971318274736404,
#   0.07631459087133408,
#   0.07540405541658401,
#   0.07016845047473907,
#   0.07688368111848831,
#   0.07301388680934906]}

# %%
#Recording History in json
import json
with open('history_Incept.json','w') as f:
  json.dump(history_Incept.history,f)

# %%
print(history_Incept.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Loading Model

# %%
print(history_Incept)
# Out:
# <keras.callbacks.History object at 0x000001308658F490>

# %%
epochs = [i for i in range(1,11)]
plt.plot(epochs,history_Incept['accuracy'],color='red',label='Training Accuracy')
plt.plot(epochs,history_Incept['val_accuracy'],color='blue',label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Visualization of Accuracy Result')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 epochs = [i for i in range(1,11)]
# ----> 2 plt.plot(epochs,history_Incept['accuracy'],color='red',label='Training Accuracy')
#       3 plt.plot(epochs,history_Incept['val_accuracy'],color='blue',label='Validation Accuracy')
#       4 plt.xlabel('No. of Epochs')
#
# TypeError: 'History' object is not subscriptable

# %% [markdown]
# ## Some other metrics to evaluate our Model

# %%
class_name = validation_set.class_names

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# %%
y_pred = InceptModel.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)

# %%
true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1)

# %%
Y_true

# %%
predicted_categories

# %%
import sklearn.metrics

from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(Y_true,predicted_categories)

# %%
# Precision Recall Fscore
print(classification_report(Y_true,predicted_categories,target_names=class_name))

# %% [markdown]
# ## Conflict Matrix Visualization

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(cm,annot=True,annot_kws={"size": 10})

plt.xlabel('Predicted Class',fontsize = 20)
plt.ylabel('Actual Class',fontsize = 20)
plt.title('Plant Disease Prediction Confusion Matrix',fontsize = 25)
plt.show()
